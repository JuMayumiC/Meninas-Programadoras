# %% [markdown]
# <a href="https://colab.research.google.com/github/JuMayumiC/Meninas-Programadoras/blob/main/Simulados%20/%20Simulado_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#
# # **👾 Simulado Avaliação #1 💻**
#
#
#
# ![image.png](data:image/png;base64,...)
#
# </center>

# %% [markdown]
# # **Medidas**
#
# **Introdução**
#
# Utilizamos o quilômetro para medir distâncias entre cidades, estados ou países. O metro é utilizado para expressar altura de pessoas, comprimentos, larguras, altura de prédios e de árvores. O centímetro é muito utilizado na medição de distâncias em mapas, tamanhos de mesas e objetos domésticos. O milímetro é utilizado na medição de parafusos e objetos muito pequenos(Por Marcos Noé. Matemático, Equipe Escola Kids)Dado um valor decimal corresponde a uma medida em metro, calcule o valor correspondente em milímetro.
#
# **Problema**
#
# Dado um valor decimal corresponde a uma medida em metro, calcule o valor correspondente em milímetro.
#
# Dica: para imprimir o valor apontado por **xis** com duas casas decimais, podemos utilizar: `print('%.2f' % xis)`
#
# **Entrada**
#
# Um valor decimal correspondente a uma medida em metros
#
# **Saída**
#
# O valor correspondente em milímetros, com zero casas decimais

# %%
vm = float(input())

vmm = vm * 1000

print('%.0f' % vmm)
# Out:
# 0.01
# 10

# %% [markdown]
# # **Futebol**
#
# **Problema**
#
# Em tempos de copa do mundo, muita gente quer praticar programação com problemas que envolvam partidas de futebol. Placar de futebol é simples: ou há empate ou ganha quem faz mais gols. Entretanto, quando um jogo é eliminatório, em caso de empate normalmente há prorrogação no tempo da partida e, se o empate persistir, ocorre a disputa de penaltis. Sua missão é fazer um programa para identificar o ganhador de uma partida, se há prorrogação e se há disputa de penaltis.
#
# **Entrada**
#
# * primeira linha: nome do primeiro time
#
# * segunda linha: nome do segundo time
#
# * as duas próximas linhas apresentam o número de gols efetuados por cada time durante o tempo normal
#
# * se houver prorrogação, as duas proximas linhas apresentam o número de gols efetuados por cada time durante a prorrogação
#
# **Saída**
#
# como nos exemplos

# %%
p1 = input()
p2 = input()

pp1 = int(input())
pp2 = int(input())

if pp1 > pp2:
  print('vitoria:', p1)
elif pp2 > pp1:
  print('vitoria:', p2)
elif pp1 == pp2:
  print('prorrogação!')
  pp1 = int(input())
  pp2 = int(input())
  if pp1 > pp2:
    print('vitoria:', p1)
  elif pp2 > pp1:
    print('vitoria:', p2)
  elif pp1 == pp2:
    print('disputa de penaltis!')
# Out:
# Espanha
# Japão
# 1
# 2
# vitoria: Japão

# %% [markdown]
# # **Submissões e Cia**
#
# **Problema**
#
# Vamos ajudar a equipe do projeto Meninas Programadoras a saberem como as alunas resolveram uma lista de exercício? Você tem que fazer um programa para verificar, para uma aluna, quantas submissões foram realizadas por ela, e quantas foram aceitas, no prazo de vigência da lista.
#
# O programa primeiro recebe o número de problemas da lista. A seguir, o programa recebe um número indefinido de linhas que podem conter as palavras 'accepted', 'error' ou 'timeout'. Quando ocorre 'timeout' não são aceitas novas submissões.
#
# **Entrada**
#
# * primeira linha: número de problemas
# * a seguir: um número indefinido de linhas que podem conter as palavras 'accepted', 'error' ou 'timeout'
#
# **Saída**
#
# Como nos exemplos

# %%
ac = 0
subc = 0
np = int(input())
sub = input()

while True:
    subc += 1
    if sub == 'accepted':
        ac += 1

    if ac == np or sub == "timeout":
        break

    sub = input()

print('submissoes:', subc)
print('aceitos:', ac)
# Out:
# 1
# error
# accepted
# submissoes: 2
# aceitos: 1

# %% [markdown]
# # **C*F mascarado**
#
# É sempre bom mascarar informações para proteger privacidade dos donos das informações.
#
# Seu programa deve ler o número de CPF (apenas números) e gerar uma mascara trocando todos os valores pares pelo asterisco.
#
#
#
# **Entrada**
#
# Os dígitos que compõem um CPF
#
# **Saída**
#
# O CPF mascarado como especificado acima

# %%
npar = [0, 2, 4, 5, 8]
cpf = input()

for i in npar:
    cpf = cpf.replace(str(i), '*')

print(cpf)
# Out:
# 13455683983
# 13***6*39*3

# %%
cpf = input()
cpf_masked = ''

for digit in cpf:
    if int(digit) % 2 == 0:
        cpf_masked += '*'
    else:
        cpf_masked += digit

print(cpf_masked)
# Out:
# 02638930903
# ***3*93*9*3

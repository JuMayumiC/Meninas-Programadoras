# %% [markdown]
# #**método count() da classe string**
#
# O método **count()** retorna o número de vezes que a substring informada como argumento ocorre na **string que ativou** o método

# %%
linha = input()
palavra = input()

nro_palavras_na_linha = linha.count(palavra)
print('[', palavra, '] ocorre', nro_palavras_na_linha, 'vez em: [', linha, ']')
# Out:
# O rato roeu a roupa do rei de Roma
# rei
# [ rei ] ocorre 1 vez em: [ O rato roeu a roupa do rei de Roma ]
# [ rei ] ocorre pela primeira vez em: [ O rato roeu a roupa do rei de Roma ] na posição: 23
# O rato roeu a roupa do *** de Roma

# %% [markdown]
# #**método find() da classe string**
#
# O método **find()** procura a substring **informada** como argumento na **string que ativou** o método, e
# > se encontrar, retorna a posição da **primeira** ocorrência
#
# > se **não** encontrar, retorna **-1**

# %%
linha = input()
palavra = input()

primeira_vez_palavra_na_linha = linha.find(palavra)

if primeira_vez_palavra_na_linha == -1:
  print('[', palavra, '] não ocorre em: [', linha, ']')
else:
  print('[', palavra, '] ocorre pela primeira vez em: [', linha, '] na posição:', primeira_vez_palavra_na_linha)

# %% [markdown]
# #**método replace() da classe string, parte 1**
#
# O método **replace()** retorna uma string na qual a substring informada como **primeiro** argumento é **substituída** pela substring informada pelo **segundo** argumento na **string que ativou** o método
# > Todas as ocorrências da substring especificada serão substituídas, a menos que algo diferente seja informado.

# %%
linha = input()
palavra = input()

tamanho_palavra = len(palavra) 
trocar = ''
for i in range(tamanho_palavra):
  trocar += '*'
linha_palavra_escondida = linha.replace(palavra, trocar)
print(linha_palavra_escondida)
# Out:
# Sabe tese, de faculdade? Aquela que se defendem? Com unhas e dentes? É dessa tese que eu estou falando. Você deve conhecer pelo menos uma pessoa que já defendeu uma tese.
# tese
# Sabe ****, de faculdade? Aquela que se defendem? Com unhas e dentes? É dessa **** que eu estou falando. Você deve conhecer pelo menos uma pessoa que já defendeu uma ****.

# %% [markdown]
# #**método replace() da classe string, parte 2**
#
# Podemos informar um **terceiro argumento** na chamada no método **replace()**
# > esse valor é um contador do **máximo de trocas** que queremos que aconteça

# %%
linha = input()
palavra = input()

tamanho_palavra = len(palavra) 
trocar = ''
for i in range(tamanho_palavra):
  trocar += '*'
linha_palavra_escondida = linha.replace(palavra, trocar, 1)
print(linha_palavra_escondida)
# Out:
# Sabe tese, de faculdade? Aquela que se defendem? Com unhas e dentes? É dessa tese que eu estou falando. Você deve conhecer pelo menos uma pessoa que já defendeu uma tese.
# tese
# Sabe ****, de faculdade? Aquela que se defendem? Com unhas e dentes? É dessa tese que eu estou falando. Você deve conhecer pelo menos uma pessoa que já defendeu uma tese.

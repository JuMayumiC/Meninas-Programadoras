# %% [markdown]
# #**Histograma** 📈
#
# O histograma, também conhecido como distribuição de frequências, é a representação gráfica em colunas ou em barras (retângulos) de um conjunto de dados previamente tabulado e dividido em classes uniformes ou não uniformes.
# > A base de cada retângulo representa uma classe.
#
# > A altura de cada retângulo representa a quantidade ou a frequência absoluta com que o valor da classe ocorre no conjunto de dados para classes uniformes ou a densidade de frequência para classes não uniformes.
#
# fonte: [Histograma Wikipedia](https://https://pt.wikipedia.org/wiki/Histograma)

# %% [markdown]
# #**Prática 2D: desenhar um histograma**
# O programa abaixo desenha um "histograma" na tela como base em valores lidos. Note que nosso histograma tem duas dimensões:
# > uma dimensão para cada linha do histograma
#
# > para cada linha, a segunda dimensão representa qual o valor correspontente àquela linha
#
# ---
# Nosso programa:
# * lê uma linha sequência de valores da entrada, considera os valores como inteiros, e gera uma lista com esses valores
# * para cada um dos valores da lista
#   * o programa inicializa uma string como vazia
#   * anexa à string o número de * correspondente ao valor
#   * imprime a lista com os os asteriscos

# %%
lista = [int(i) for i in input().split()]
for i in lista:
  linha = ''
  for j in range(i):
    linha += '*'
  print(linha)
# Out:
# 9 1 8 2 7 3 6 4 0 5
# *********
# *
# ********
# **
# *******
# ***
# ******
# ****
#
# *****

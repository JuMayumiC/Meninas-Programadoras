# %% [markdown]
# #**Exercícios com novidades**

# %% [markdown]
# #**Calcular o delta de uma equação de 2o grau completa**
#
# ```
# ALGORITMO
# Obter coeficientes da entrada como valores inteiros
# Calcular o delta
# Informar o número de raízes da equação
# ```
#
# **Elementos conhecidos**
# * leitura de inteiros
# * strings constantes demarcadas com aspas simples
# * operações de multiplicação e subtração de inteiros
# * operação de soma de strings
# * condicional if-elif-else
# * impressão de string
#
# **Novidade**
# * função str() para converter o valor recebido em uma string
# * neste exemplos passamos um valor inteiro
# * podemos passar decimal também
#
# **Faça você mesma**
# * mude o exercício para ler decimais da entrada
# * apresente o resultado de maneiras diferentes

# %%
# Calcular o delta de uma equação de 2o grau completa
# Notem, na preparação inicial da mensagem de resposta,
#   o uso da função str() para converter o valor de delta, 
#   que é um inteiro, para uma string; isso permite concactenar,
#   por meio do operador de adição, a string resultante 
#   com a primeira parte de mensagem

a = int(input())                  #obter os coeficientes
b = int(input())
c = int(input())
delta = (b * b) - (4 * a * c)     # calcular o delta
resposta = 'delta= ' + str(delta) # preparar resposta
if delta < 0:
  resposta = resposta + ': sem raízes reais'
elif delta == 0:
  resposta = resposta + ': uma raíz real'
else:
  resposta = resposta + ': duas raízes'
print(resposta)
# Out:
# -1
# 2
# 3
# delta= 16: duas raízes

# %% [markdown]
# # Calcular as raízes de uma equação de 2o grau completa
# Os coeficientes da entrada podem ser valores decimais.
#
# ```
# ALGORITMO
# calcular o delta
# se delta < 0
#    informar ausência de raizes
# senao se delta == 0
#    calcular raiz única
# senão
#    calcular raiz quadrada de delta
#    calcular as duas raizes
# informar o resultado
# ```
#
# **Elementos conhecidos**
# * leitura de decimais
# * operações com strings constantes
# * operações aritméticas soma, multiplicação, divisão
# * condicional if-elif-else
# * impressão de string
# * função str() para converter o valor recebido em uma string
#
# **Novidade**
# * uso de potência de 1/2 para cálculo de raiz quadrada
#
# **Faça você mesma**
# * apresente o resultado de maneiras diferentes

# %%
# Calcular as raízes de uma equação de 2o grau completa

a = float(input())                  #obter os coeficientes
b = float(input())
c = float(input())
delta = (b * b) - (4 * a * c)     # calcular o delta
print(delta)
resposta = 'delta= ' + str(delta) # preparar resposta
if delta < 0:
  resposta = resposta + ': sem raízes reais'
elif delta == 0:
  x = -b / (2 * a)
  resposta = resposta + ': uma raíz real ('+ str(x)+')'
else:
  raiz2_delta = (delta)**(1/2)     # usamos potência de 1/2 para calcular a raiz quadrada
  print(raiz2_delta)
  x1 = (-b + raiz2_delta) / (2 * a)   
  x2 = (-b - raiz2_delta) / (2 * a)  
  resposta = resposta + ': duas raízes reais (' + str(x1) + ', ' + str(x2)+')'
print(resposta)
# Out:
# -1
# 0
# 9
# 36.0
# 6.0
# delta= 36.0: duas raízes reais (-3.0, 3.0)

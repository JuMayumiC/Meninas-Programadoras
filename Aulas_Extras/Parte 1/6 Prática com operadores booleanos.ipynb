# %% [markdown]
# #**Prática com operadores booleanos I**
#
# Vamos observar
# * constantes e tabelas-verdade
# * o resultado das operações envolvendo dois valores

# %%
# vamos observar o resultado das operações envolvendo dois valores
# constantes e tabelas-verdade

print(bool(True), bool(False))            # as constantes booleanas
print(bool(1), bool(0))                   # mapeamento de valores inteiros para booleanos
print(not 1, not 0)                       # tabela-verdade operador or
print(0 or 0, 0 or 1, 1 or 0, 1 or 1)     # tabela-verdade operador or 
print(0 and 0, 0 and 1, 1 and 0, 1 and 1) # tabela-verdade operador and
# Out:
# True False
# True False
# False True
# 0 1 1 1
# 0 0 0 1

# %% [markdown]
# #**Prática com operadores booleanos II**
#
# Vamos
# * obter três valores inteiros que devem ser 0 ou 1
# * avaliar operações lógicas entre os valores obtidos

# %%
a = int(input())
b = int(input())
c = int(input())
print(bool(a), bool(b), bool(c))
print((not a), (not b), not(c))
print((a or b), (a or b), (a or c), (b or c))
print((a and b), (a and b), (a and c), (b and c))
print((a or b or c), (a and b and c), (a and b or c), (a or b and c))
print(not(a or b), not(a or c), not(b or c))
print(not(a and b), not(a and c), not(b and c))
# Out:
# 1
# 0
# 1
# True False True
# False True False
# 1 1 1 1
# 0 0 1 0
# 1 0 1 1
# False False False
# True False True

# %% [markdown]
# #**Prática com operadores booleanos III**
#
# Vamos
# * **obter dois valores** inteiros que devem ser 0 ou 1
# * testar os valores obtidos com **operações condicionais** e
# * realizar operações lógicas de modo que o resultado obtido seja **sempre verdadeiro**

# %%
a = int(input())
b = int(input())

if a:
  if b: 
    print(a, 'and', b, ':', (a and b))
  else:
    print(a, 'and not', b, ':', (a and not b))
else:
  if b:
    print('not', a, 'and', b, ':', (not a and b))
  else:
    print('not', a, 'and', 'not', b, ':', (not a and not b))
print('fim')
# Out:
# 0
# 1
# not 0 and 1 : 1
# fim

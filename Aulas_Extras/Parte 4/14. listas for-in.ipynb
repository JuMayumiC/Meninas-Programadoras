# %% [markdown]
# #**Listas**

# %%
vazia = []
vogais = ['a', 'o', 'i', 'u', 'e']
frutas = ['banana', 'laranja', 'abacaxi']
alunas = ['Paola', 'Nathane', 'Ana', 'Filipa']
notas = [10, 9.5, 10, 9.0]
print(vazia)
print(vogais)
print(frutas)
print(alunas)
print(notas)
# Out:
# []
# ['a', 'o', 'i', 'u', 'e']
# ['banana', 'laranja', 'abacaxi']
# ['Paola', 'Nathane', 'Ana', 'Filipa']
# [10, 9.5, 10, 9.0]

# %%
lista = []
print(lista)
lista.append('Ana')
print(lista)
lista.append('Paola')
print(lista)
lista.append('Nathane')
print(lista)
lista.append('Ariele')
print(lista)
lista.insert(10,'Agnes')  # nao gostei
print(lista)
lista.insert(1, 'Laura')
print(lista)
# Out:
# []
# ['Ana']
# ['Ana', 'Paola']
# ['Ana', 'Paola', 'Nathane']
# ['Ana', 'Paola', 'Nathane', 'Ariele']
# ['Ana', 'Paola', 'Nathane', 'Ariele', 'Agnes']
# ['Ana', 'Laura', 'Paola', 'Nathane', 'Ariele', 'Agnes']

# %%
lista = []
print(lista)
lista.append('Ana')
print(lista)
lista.append('Paola')
print(lista)
lista.append('Nathane')
print(lista)
lista.append('Ariele')
print(lista)
nome = lista.pop()  # ultimo
print(nome, '-', lista)
lista.insert(1, 'Laura')
print(lista)
nome = lista.pop(0)  # primeiro
print(nome, '-', lista)
# Out:
# []
# ['Ana']
# ['Ana', 'Paola']
# ['Ana', 'Paola', 'Nathane']
# ['Ana', 'Paola', 'Nathane', 'Ariele']
# Ariele - ['Ana', 'Paola', 'Nathane']
# ['Ana', 'Laura', 'Paola', 'Nathane']
# Ana - ['Laura', 'Paola', 'Nathane']

# %%
total = int(input())
meninas = []
for valor in range(total):
  menina = input()
  meninas.append(menina)
print(meninas)

for menina in meninas:
  print(menina)

# i = int(input())
# print(meninas[i])
# Out:
# 4
# Filipa
# Pri
# Paola
# Nat
# ['Filipa', 'Pri', 'Paola', 'Nat']
# Filipa
# Pri
# Paola
# Nat

# %%
total = int(input())
meninas = []
for valor in range(total):
  menina = input()
  meninas.append(menina)
print(meninas)

for i in range(total):
  print(meninas[i])
# Out:
# 5
# Ca
# Pao
# Val
# Pri
# Fi
# ['Ca', 'Pao', 'Val', 'Pri', 'Fi']
# Ca
# Pao
# Val
# Pri
# Fi

# %%
total = int(input())
meninas = []
for valor in range(total):
  menina = input()
  meninas.append(menina)
print(meninas)

for i in range(len(meninas)):
  print(meninas[i])
print(meninas)
# Out:
# 5
# A
# J
# D
# R
# T
# ['A', 'J', 'D', 'R', 'T']
# A
# J
# D
# R
# T
# ['A', 'J', 'D', 'R', 'T']

# %%
total = int(input())
meninas = []
for valor in range(total):
  menina = input()
  meninas.append(menina)
print(meninas)

for i in range(len(meninas)):
  print(meninas.pop())
print(meninas)
# Out:
# 5
# Bia
# Carol
# Ana
# Duda
# Vera
# ['Bia', 'Carol', 'Ana', 'Duda', 'Vera']
# Vera
# Duda
# Ana
# Carol
# Bia

# %%
total = int(input())
meninas = []
for valor in range(total):
  menina = input()
  meninas.append(menina)
print(meninas)

for i in range(len(meninas)):
  print(meninas.pop(0))
print(meninas)
# Out:
# 4
# Ana
# Bia
# Duda
# Cida
# ['Ana', 'Bia', 'Duda', 'Cida']
# Ana
# Bia
# Duda
# Cida
# []

# %%
lista = ['Vera', 'Olga', 'Bia', 'Mariana', 'Gabriela']
print(lista)
lista.sort()
print(lista)
# Out:
# ['Vera', 'Olga', 'Bia', 'Mariana', 'Gabriela']
# ['Bia', 'Gabriela', 'Mariana', 'Olga', 'Vera']

# %%
lista = ['Vera', 'Olga', 'Bia', 'Mariana', 'Gabriela']
print(lista)
ordenada = sorted(lista)
print(lista)
print(ordenada)
# Out:
# ['Vera', 'Olga', 'Bia', 'Mariana', 'Gabriela']
# ['Vera', 'Olga', 'Bia', 'Mariana', 'Gabriela']
# ['Bia', 'Gabriela', 'Mariana', 'Olga', 'Vera']

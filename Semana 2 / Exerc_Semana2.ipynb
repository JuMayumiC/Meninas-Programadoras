# %% [markdown]
# <a href="https://colab.research.google.com/github/JuMayumiC/Meninas-Programadoras/blob/main/Semana%202%20/%20Exerc_Semana2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#
# # **👾 Resolução da lista de exercícios da SEMANA 1** 💻
#
# ![image.png](data:image/png;base64,...)
#
# </center>

# %% [markdown]
# # **Par**
#
# **Qual problema você tem que resolver?**
#
# Leia um valor inteiro e verifique se ele é par
#
# **Entrada**
#
# Uma linha com um valor inteiro
#
# **Saída**
#
# S ou N, caso seja par ou não

# %%
n = int(input())
r = n % 2 

if r == 0 :
  print("S")
else :
  print("N")
# Out:
# 1
# N

# %% [markdown]
# # **Bandeira**
#
# As crianças estão aprendendo a desenhar a bandeira brasileira e precisam da sua ajuda. Elas sabem o nome das cores mas não sabem o nome das figuras geométricas. Seu programa deve ler o nome de uma cor e informar qual a forma geométrica correspondente.
#
# **Entrada**
#
# Ver exemplos.
#
# **Saída**
#
# Ver exemplos.

# %%
cor = input()

if cor in "azul" :
  print("circunferência")
elif cor in "amarelo" :
  print("losango")
elif cor in "verde" :
  print("retângulo")
elif cor in "branco" :
  print("faixa")
else :
  print("não tem essa cor")
# Out:
# roxo
# não tem essa cor

# %% [markdown]
# # **Avançar ou não avançar? eis a questão**
#
# **Avançar ou não avançar? eis a questão..**
#
# Carros autônomos devem obedecer as mesmas regras que os motoristas humanos e, além disso, serem mais cuidadosos ainda. Por isso, quando você for fazer o programa de um carro autônomo, você vai fazer o carro avançar apenas se o semáforo estiver verde.
#
# Seu programa deve ler a cor do semáforo (verde/amarelo/vermelho) e dar o comando correto para o carro (avançar ou parar)
#
# **Entrada**
#
# Ver exemplos
#
# **Saída**
#
# Ver exemplos

# %%
cor = input()

if cor in "verde":
  print('avançar')
elif cor in 'amarelo' or 'vermelho':
  print("parar")
# Out:
# amarelo
# parar

# %% [markdown]
# # **A Compra Responsável**
#
# Uma pessoa está fazendo uma compra por um site Web. Ela colocou um conjunto de itens no carrinho de compras, e vai pagar a compra com PIX.
#
# **Essa pessoa decidiu nunca gastar mais do ela realmente tem.**
#
#  Seu programa deve ler duas linhas, com um valor inteiro cada.
#
# * O primeiro valor corresponde ao valor em dinheiro que a pessoa tem na conta do banco.
# * O segundo valor corresponde ao total calculado no carrinho de compras.
#
# Seu programa deve verificar se a pessoa pode ou não realizar a compra de modo a respeitar sua própria decisão, e emitir mensagens correspondentes:
#
# * se o saldo for suficiente, informar 'pode comprar tudo'
# * caso contrário, informar 'saldo insuficiente'
#
# **Entrada**
#
# Duas linhas, com um valor inteiro cada (i.e. apenas valores inteiros)
#
# Uma entre as duas alternativas indicadas nos exemplos.
#
# **Saída**
#
# Uma entre as duas alternativas indicadas nos exemplos.

# %%
saldo = int(input())
compra = int(input())

if saldo >= compra:
  print("pode comprar tudo")
if saldo < compra:
  print("saldo insuficiente")
# Out:
# 100
# 110
# saldo insuficiente

# %% [markdown]
# # **A Compra Responsável Informada**
#
# Uma pessoa está fazendo uma compra por um site Web.
#
# Ela colocou um conjunto de itens no carrinho de compras, e vai pagar a compra com PIX.
#
# Essa pessoa decidiu nunca gastar mais do ela realmente tem.
#
# Seu programa deve ler duas linhas, com um valor inteiro cada.
#
# * o primeiro valor corresponde ao valor em dinheiro que a pessoa tem na conta do banco
#
# * o segundo valor corresponde ao total calculado no carrinho de compras.
#
# Seu programa deve verificar se a pessoa pode ou não realizar a compra de modo a respeitar sua própria decisão, e emitir mensagens correspondentes.
#
# Caso não deve ser efetuada para respeitar a decisão, informar 'seu saldo é insuficiente para essa compra'.
#
# **Entrada**
#
#  Duas linhas, com um valor inteiro cada (i.e. apenas valores inteiros)
#
# **Saída**
#
# Como especificado acima e indicado nos exemplos

# %%
saldo = int(input())
compra = int(input())

if saldo >= compra:
  print("se você comprar tudo o saldo será:", saldo - compra)
if saldo < compra:
  print("seu saldo é insuficiente para essa compra")
# Out:
# 100
# 87
# se você comprar tudo o saldo será: 13

# %% [markdown]
# # **Idade para votar**
#
# Seu programa deve ler um valor inteiro, correspondente à idade de uma pessoa, e informar se essa pessoa tem idade para votar ou ainda é jovem demais.
#
# Veja as mensagens esperadas nos exemplos.
#
# **Entrada**
#
# Um valor inteiro
#
# **Saída**
#
# Uma linha, como nos exemplos.

# %%
idade = int(input())

if idade >= 16:
  print("Tem idade para votar")
if idade < 16: 
  print("Jovem demais para votar, espere até 16")
# Out:
# 13
# Jovem demais para votar, espere até 16

# %% [markdown]
# # **Voto obrigatório ou facultativo?**
#
# Seu programa deve per um valor inteiro, correspondente à idade de uma pessoa, e informar se essa pessoa tem idade para votar e, se for, se o voto é obrigatório ou facultativo.
#
# Lembre que o voto é facultativo para quem tem 16 e 17 anos, ou para quem tem 70 anos ou mais. Entre 18 e 69 anos, o voto é obrigatório.
#
# **Entrada**
#
# Um linha com um valor inteiro
#
# **Saída**
#
# Veja as mensagens esperadas no exemplos.

# %%
idade = int(input())

if idade == 16 or idade == 17 or idade >= 70:
  print('Seu voto é facultativo: você pode votar ou não')
elif idade < 16:
  print("Jovem demais para votar, espere até 16")
elif 69 >= idade >= 18:
  print("Seu voto é obrigatório")
# Out:
# 21
# Seu voto é obrigatório

# %% [markdown]
# # **Mes: de número para nome abreviado**
#
# Dado o número correspondente a um dos meses do ano, seu programa deve imprimir qual a abreviatura do mês correspondente.
#
# **Entrada**
#
# Um inteiro entre 1 e 12
#
# **Saída**
#
# A abreviatura do nome do mês correspondente, com três letras minúsculas

# %%
num = int(input())

if num == 1:
  print('jan')
if num == 2:
  print('fev')
if num == 3:
  print('mar')
if num == 4:
  print('abr')
if num == 5:
  print('mai')
if num == 6:
  print('jun')
if num == 7:
  print('jul')
if num == 8:
  print('ago')
if num == 9:
  print('set')
if num == 10:
  print('out')
if num == 11:
  print('nov')
if num == 12:
  print('dez')
# Out:
# 5
# mai

# %% [markdown]
# # **Final da placa**
#
# Para promover o rodízio da circulação de veículos, algumas cidades definem regras que associam o final da placa do veículo ao um dia da semana em que o veículo não deve circular.
#
# Alguns aplicativos permitem que você informe a placa de seu veículo e você resolveu investigar como faria isso em um programa.
#
# Seu programa deve ler um inteiro que corresponde aos dígitos da placa de um veículo, e verificar qual é o último dígido daquela placa.
#
# **Entrada**
#
# Um valor inteiro entre 0 e 9999
#
# **Saída**
#
# Um valor inteiro entre 0 e 9

# %%
placa = int(input())

ld = placa % 10

print(ld)
# Out:
# 1234
# 4

# %% [markdown]
# # **Rodízio de automóveis**
#
# Algumas cidades realizam rodízio de veículos.
#
# * Para isso, emitem regras que associam o final da placa do veículo ao um dia da semana em que o veículo não deve circular pois, se o fizer, vai receber multa.
#
# * Alguns aplicativos permitem que você informe a placa de seu veículo, já notou? Como será que fazem?
#
# Seu programa deve ler um inteiro que corresponde ao número da placa de um veículo, e informar em qual dia da semana aquele veículo não deve circular.
#
# As regras são:
#
# * Na segunda-feira não devem circular carros com final 1 e 2
#
# * Na terça-feira não devem circular carros com final 3 e 4
#
# * Na quarta-feira não devem circular carros com final 5 e 6
#
# * Na quinta-feira não devem circular carros com final 7 e 8
#
# * Na sexta-feira não devem circular carros com final 9 e 0
#
# **Entrada**
#
# Uma linha com um valor inteiro entre 0 e 9999
#
# **Saída**
#
# Um linha com o dia da semana, como nos exemplos

# %%
placa = int(input())

ld = placa % 10

if ld == 1 or ld == 2:
  print('segunda-feira')
elif ld == 3 or ld == 4:
  print('terça-feira')
elif ld == 5 or ld == 6:
  print('quarta-feira')
elif ld == 7 or ld == 8:
  print('quinta-feira')
elif ld == 9 or ld == 0:
  print('sexta-feira')
# Out:
# 9874
# terça-feira

# %% [markdown]
# # **Romanos**
#
# **Valores Romanos**
#
# Seu programa deve ler uma letra e verificar a qual algarismo romano ela corresponde.
#
# Garante-se que apenas um dos seguintes valores será fornecido como entrada: I, V, X, L, C, D, M
#
# **Entrada**
#
# Uma linha com uma letra
#
# **Saída**
#
# Um linha com um valor inteiro

# %%
l = input()

if l == 'I':
  print(1)
if l == 'V':
  print(5)
if l == 'X':
  print(10)
if l == 'L':
  print(50)
if l == 'C':
  print(100)
if l == 'D':
  print(500)
if l == 'M':
  print(1000)
# Out:
# V
# 5

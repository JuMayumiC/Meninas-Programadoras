# %% [markdown]
# <center>
#
# # **👾 Resolução da lista de exercícios da SEMANA 1** 💻
#
#
#
#
#
#
#
#
# ![AnyaPython.jpg](data:image/jpeg;base64,...)
# </center>

# %% [markdown]
# #**Papagaio Engraçado**
#
# No parque ecológico de São Carlos há um papagaio engraçado. Ele adora aprender palavras novas, mas sempre as repete duas vezes.  As crianças de divertem demais!
#
# Seu programa deve imitar o papagaio engraçado >:-)
#
# **Entrada**
#
# Uma linha
#
# **Saída**
#
# Como nos exemplos

# %%
linha = input()
print(linha, linha)
# Out:
# oiee
# oiee oiee

# %% [markdown]
# #**Simplificações do mundo real**
#
# **Qual problema você tem que resolver?**
#
# Seu programa deve ler três informações sobre um animal e imprimir uma mensagem que descreve o animal com base nessas informações, como ilustrado nos exemplos
#
# **O que é fornecido como entrada?**
#
# Três linhas: nome comum pelo qual a raça do animal é conhecida; um atributo do animal; uma ação que o animal pode realizar.
#
# **O que seu programa deve produzir?**
#
# Uma única linha com a mensagem que descreve o animal com base informações lidas. A mensagem deve seguir o modelo ilustrado nos exemplos

# %%
animal = input() 
atributo = input()
ação = input() 
print('Um', animal, 'tem', atributo, 'e pode', ação)
# Out:
# pinguim
# nadadeiras
# voar
# Um pinguim tem nadadeiras e pode voar

# %% [markdown]
# #**Somando strings**
#
# **Problema**
#
# Seu programa deve ler três strings quaisquer e imprimir a soma dessas strings duas a duas, em todas as ordens possíveis.
#
# **O que é fornecido como entrada?**
#
# Três linhas, cada uma com uma string qualquer
#
# **O que seu programa deve produzir?**
#
# Seis linhas, cada uma som a soma das string duas a duas. A ordem da impressão é a mesma ordem na qual as strings foram dadas, como nos exemplos.

# %%
a = input()
b = input()
c = input()

print(a + b) 
print(a + c)
print(b + a)
print(b + c) 
print(c + a) 
print(c + b)
# Out:
# ju
# may
# c
# jumay
# juc
# mayju
# mayc
# cju
# cmay

# %% [markdown]
# #**Bem-vinda**
#
#   Seu programa deve ler um nome oferecido como entrada e imprimir uma mensagem de boas vindas como saída
#
# **Entrada**
#
# Uma linha com um nome
#
# **Saída**
#
# Mensagem de boas vindas, como no exemplo

# %%
nome = input()
mensagem = 'Bem-vinda'

print(mensagem, nome)
# Out:
# May
# Bem-vinda May

# %% [markdown]
# #**Cadastro Light**
#
# **PROBLEMA**
#
# Vamos montar um nome completo?
#
# Neste exercício, sua tarefa é fazer um programa vai imprimir o nome completo de uma pessoa, anexando o nome ao sobrenome
#
# **Entrada**
#
# Seu programa deve ler duas linhas com dados de uma pessoa
# na primeira linha, uma sequência de caracteres correspondendo a um nome
# na segunda linha, uma sequência de caracteres correspondendo ao sobrenome
#
# **Saída**
#
# Uma linha: o nome seguido do sobrenome

# %%
nome = input()
sobrenome = input()

print(nome, sobrenome)
# Out:
# Mayumi
# Costa
# Mayumi Costa

# %% [markdown]
# #**Próximo**
#
# Seu programa deve ler um inteiro, calcular o próximo valor inteiro, e imprimir o valor calculado.
#
# **Entrada**
#
# Um valor inteiro
#
# **Saída**
#
# Um valor inteiro

# %%
numero = int(input())

print(numero + 1)
# Out:
# 3
# 4

# %% [markdown]
# #**O Anterior**
#
# Seu programa deve ser um inteiro, calcular o valor inteiro anterior, e imprimir o valor calculado.
#
# **Entrada**
#
# Um valor inteiro
#
# **Saída**
#
# Um valor inteiro

# %%
numero = int(input())

print(numero - 1)
# Out:
# 1
# 0

# %% [markdown]
# #**O Dobro**
#
# Seu programa deve ser um inteiro, calcular o dobro do valor lido, e imprimir o valor calculado.
#
# **Entrada**
#
# Um valor inteiro
#
# **Saída**
#
# Um valor inteiro

# %%
numero = int(input())

print(numero * 2)
# Out:
# 5
# 10

# %% [markdown]
# #**A Metade**
#
# Seu programa deve ser um inteiro, calcular a metade do valor lido, e imprimir o valor calculado.
#
# **Entrada**
#
# Um valor inteiro
#
# **Saída**
#
# Um valor decimal (que é o resultado padrão de uma divisão)

# %%
numero = int(input())

print(numero / 2)
# Out:
# 7
# 3.5

# %% [markdown]
# #**Divisão Inteira**
#
# Seu programa deve ler dois valores inteiros, um em cada linha, e calcular
#
# * o resultado da divisão inteira do primeiro pelo segundo e
#
# * o resultado do resto da divisão inteira do primeiro pelo segundo
#
# * e imprimir os valores calculados.
#
# **Entrada**
#
# Duas linhas, cada uma com um valor inteiro
#
# **Saída**
#
# Duas linhas, cada uma com um valor inteiro conforme calculado

# %%
numero = int(input())
divisor = int(input())

print(numero // divisor)
print(numero % divisor)
# Out:
# 10
# 5
# 2
# 0

# %% [markdown]
# #**Rejuvenescimento Light**
#
# **Qual problema você tem que resolver?**
#
# Seu programa deve ler dois valores, nome e idade, e imprimi-los na ordem inversa, diminuindo a idade em dois anos :-)
#
# **Entrada**
#
# Duas linhas: a primeira com uma string (nome) e a segunda com um inteiro (idade)
#
# **Saída**
#
# Duas linhas: a primeira com a idade diminuída em dois anos, e a segunda com o nome

# %%
nome = input()
idade = int(input())

print(idade - 2)
print(nome)
# Out:
# May
# 16
# 14
# May

# %% [markdown]
# #**PIN perigoso**
#
# **Problema**
#
# Todo mundo sabe que não se deve colocar data de aniversário como PIN, certo? Só que é uma pena, porque é tão mais fácil de lembrar do que valores arbitrários.
#
# Por conta disso, você bolou uma estratégia para gerar um código de quatro dígitos: em vez de colocar direto o ano de aniversário de alguém, você soma os anos de datas importantes para você (por exemplo, ano em que fez 16 anos e tirou seu título de leitor, e ano em que entrou na faculdade).
#
# Observe os exemplos ilustrativos.
#
# **Entrada**
#
# Ver exemplos
#
# **Saída**
#
# Ver exemplos

# %%
data1 = int(input())
data2 = int(input())

print(data1 + data2)
# Out:
# 2020
# 2022
# 4042

# %% [markdown]
# #**Compra questionável**
#
# Uma pessoa está fazendo uma compra por um site Web. Ela colocou um conjunto de itens no carrinho de compras, e vai pagar a compra com PIX. Essa pessoa tem cheque especial na conta, o que significa que ela pode gastar mais do que realmente tem mas vai pagar juros absurdos por isso.
#
# Seu programa deve ler duas linhas, com um valor inteiro cada. O primeiro valor corresponde ao valor em dinheiro que a pessoa tem na conta do banco. O segundo valor corresponde ao total calculado no carrinho de compras. Seu programa deve calcular qual o saldo na conta depois que a pessoa pagar a conta com PIX.
#
# **Entrada**
#
# Duas linhas contendo um valor inteiro cada
#
# **Saída**
#
# Um valor inteiro

# %%
saldo = int(input())
despesa = int(input())

print(saldo - despesa)
# Out:
# 400
# 100
# 300

# %% [markdown]
# #**O aumento no salário**
#
# Seu programa deve ler duas linhas, com um valor inteiro cada. O primeiro valor corresponde ao salário de uma pessoa. O segundo valor corresponde à porcentagem de aumento que deve ser adicionada ao salário. Seu programa deve calcular o valor correspondente ao aumento do salário informado, quando aplicada a porcentagem informada, e imprimir o valor calculado.
#
# **Entrada**
#
# Duas linhas, cada uma com um valor inteiro
#
# **Saída**
#
# Veja os exemplos :-)

# %%
salario = int(input())
aumento = int(input())

print(salario * aumento / 100)
# Out:
# 1000
# 10
# 100.0

# %% [markdown]
# # **O salario reajustado**
#
# Seu programa deve ler duas linhas, com um valor inteiro cada. O primeiro valor corresponde ao salário de uma pessoa. O segundo valor corresponde à porcentagem de aumento que deve ser adicionada ao salário. Seu programa deve calcular o novo salário, e imprimir o valor calculado.
#
# **Entrada**
#
# Duas linhas, cada uma com um valor inteiro
#
# **Saída**
#
# O valor decimal calculado

# %%
salario = int(input())
aumento = int(input())

print(salario + salario * aumento / 100)
# Out:
# 100
# 25
# 125.0

# %% [markdown]
# # **Decimais à moda antiga**
#
# **Que problema você tem que resolver**
#
# Seu programa deve ler um valor com casas decimais e apresentá-lo com 2, 4, 6, 8 e 10 casas decimais
#
# **Entrada**
#
# Um valor com casas decimais
#
# **Saída**
#
# Cinco linhas, como nos exemplos

# %%
 
valor = float(input())
print('%.2f' % valor) 
print('%.4f' % valor) 
print('%.6f' % valor) 
print('%.8f' % valor) 
print('%.10f' % valor)
# Out:
# 3.14159265358979323846
# 3.14
# 3.1416
# 3.141593
# 3.14159265
# 3.1415926536

# %% [markdown]
# # **Gorjeta**
#
# **Problema:** Dados o total de uma conta (valor decimal) e a porcentagem escolhida pelo cliente para a gorjeta (valor inteiro), calcule o valor final da conta (com duas casas decimais)
#
# * Dica: para imprimir o valor apontado por xis com duas casas decimais, podemos utilizar: print('%.2f' % xis)
#
# **Entrada**
#
# Primeira linha: valor da conta (decimal). Segunda linha: valor da porcentagem da gorjeta (inteiro).
#
# **Saída**
#
# Valor total da conta, com duas casas decimais.

# %%
conta = float(input())
gorjeta = int(input())
xis = conta + conta * gorjeta / 100

print('%.2f' % xis)
# Out:
# 100
# 1
# 101.00

# %% [markdown]
# # **Minuteira**
#
# **Quantos minutos de monitoria você fez?**
#
# Ajude os monitores a calcularem quantos minutos de monitoria você fez, a partir do número de horas e minutos que você participou.
#
# **Entrada**
#
# Primeira linha: número de horas
#
# Segunda linha: número de minutos
#
# **Saída**
#
# Total de minutos

# %%
horas = int(input())
minutos = int(input())

print(horas * 60 + minutos)
# Out:
# 1
# 35
# 95

# %% [markdown]
# # **Horas e minutos**
#
# **Problema**
#
# Dado um número de minutos, seu programa deve calcular os números de horas e de minutos correspondentes.
#
# **Entrada**
#
# Um linha: número de minutos
#
# **Saída**
#
# Como nos exemplos

# %%
minutos = int(input())

print(str(minutos) + 'min', '=', str(minutos // 60) + 'h' + str(minutos % 60) + 'min')
# Out:
# 66
# 66min = 1h6min

# %% [markdown]
# # **O desafio do bolo perfeito**
#
# **O desafio do bolo perfeito**
#
# Sabe aquele bolo que você quer fazer lá creche perto da sua casa? Então... o risco é grande de não ficar perfeito porque na cozinha da creche as xícara e as colheres são todas de tamanhos diferentes daqueles que você tem na sua casa... e agora?
#
# Você estudou e aprendeu que, de modo geral, as receitas culinárias assumem o seguinte:
#
# * uma xícara equivale a 240 ml
#
# * uma colher de sopa equivale a 15 ml
#
# * uma colher de chá equivale a 5 ml
#
# O que o seu programa tem que fazer?
#
# Usar as equivalências acima para apresentar em mililitros os valores das receitas que você e outras pessoas vão usar na creche
#
# **Entrada**
#
# Três linhas: números de xícaras da receita; números de colheres de sopa da receita, números de colheres da chá da receita
#
# Nota: se uma receita não utilizar alguma das medidas, o valor correspondente é dado como 0 (zero)
#
# **Saída**
#
# O volume equivalente em ml para cada uma das porções necessárias à receita, como nos exemplos

# %%
xicara = int(input())
colhersopa = int(input())
colhercha = int(input())

print(str(xicara * 240) + ' ml')
print(str(colhersopa * 15) + ' ml')
print(str(colhercha * 5) + ' ml')
# Out:
# 1
# 2
# 3
# 240 ml
# 30 ml
# 15 ml

# %% [markdown]
# # **ENEM #1**
#
# **Qual problema você tem que resolver?**
#
# Dados as notas em cada área obtidas por uma candidata mas provas do ENEM, e os pesos de cada área,  apresente o total de pontos correspondentes.
#
# **O que é fornecido como entrada?**
#
# Dez linhas um valor cada: cinco notas e cinco pesos, na mesma ordem das notas
#
# **O que seu programa deve produzir?**
#
# Ver exemplos
#
# **Exemplos de entrada e saída**
#
# Atenção: seu programa deve funcionar para quaisquer valores...  é isso o que um programa faz: funciona para qualquer caso...

# %%
nota1 = float(input())
nota2 = float(input())
nota3 = float(input())
nota4 = float(input())
nota5 = float(input())
peso1 = float(input())
peso2 = float(input())
peso3 = float(input())
peso4 = float(input())
peso5 = float(input())

print(str((nota1 * peso1 + nota2 * peso2 + nota3 * peso3 + nota4 * peso4 + nota5 * peso5) / (peso1 + peso2 + peso3 + peso4 + peso5) ))
# Out:
# 100
# 200
# 300
# 200
# 100
# 3
# 2
# 2
# 2
# 1
# 180.0
